# %%
getwd()
# Out:
# [1] "/Users/carolinedesouza/Documents/SCTLD/Coral_Code/PANAMA_Code"

# %%
# Import Panama.csv
read.csv("PAN-BDT_ColonyData_copy.csv")
# Out:
#     X   Date_initial_tag Transect        Transect_num Current_tag_num Species
# 1    5  9/10/22          STRI Reef       1             5              CNAT
# 2    6  9/10/22          STRI Reef       1             6              CNAT
# 3   16  9/10/22          STRI Reef       1            16              CNAT
# 4   23  9/10/22          STRI Reef       1            23              CNAT
# 5   24  9/10/22          STRI Reef       1            24              CNAT
# 6   26  9/10/22          STRI Reef       1            26              CNAT
# 7    2  9/10/22          STRI Reef       1             2              MCAV
# 8    8  9/10/22          STRI Reef       1             8              MCAV
# 9   11  9/10/22          STRI Reef       1            11              MCAV
# 10  17  9/10/22          STRI Reef       1            17              MCAV
# 11  27  9/10/22          STRI Reef       1            27              MCAV
# ...

# %%
# making a data frame for all three sites
Combined_Colony_Condition_Frame <- data.frame(Transect, X092022_Condition, X102023_Condition)
Combined_Colony_Condition_Frame
# Out:
# Error in data.frame(Transect, X092022_Condition, X102023_Condition): object 'Transect' not found
# Traceback:
#
# 1. data.frame(Transect, X092022_Condition, X102023_Condition)

# %%
library(tidyverse)
library(vegan)
library(phyloseq)
library(dplyr)
library(ggplot2)
library(stringr)
# Out:
# Error in library(tidyverse): there is no package called ‘tidyverse’
# Traceback:
#
# 1. library(tidyverse)

# %%
# Install from CRAN
install.packages("tidyverse")
# Out:
# also installing the dependencies ‘fastmap’, ‘colorspace’, ‘sys’, ‘bit’, ‘ps’, ‘sass’, ‘cachem’, ‘farver’, ‘labeling’, ‘munsell’, ‘RColorBrewer’, ‘viridisLite’, ‘rappdirs’, ‘rematch’, ‘askpass’, ‘bit64’, ‘prettyunits’, ‘processx’, ‘evaluate’, ‘highr’, ‘xfun’, ‘yaml’, ‘bslib’, ‘fontawesome’, ‘htmltools’, ‘jquerylib’, ‘tinytex’, ‘backports’, ‘ellipsis’, ‘generics’, ‘glue’, ‘lifecycle’, ‘memoise’, ‘blob’, ‘DBI’, ‘R6’, ‘tidyselect’, ‘vctrs’, ‘withr’, ‘data.table’, ‘gtable’, ‘isoband’, ‘scales’, ‘gargle’, ‘cellranger’, ‘curl’, ‘ids’, ‘rematch2’, ‘cpp11’, ‘pkgconfig’, ‘mime’, ‘openssl’, ‘timechange’, ‘fansi’, ‘utf8’, ‘systemfonts’, ‘textshaping’, ‘clipr’, ‘vroom’, ‘tzdb’, ‘progress’, ‘callr’, ‘fs’, ‘knitr’, ‘rmarkdown’, ‘selectr’, ‘stringi’, ‘broom’, ‘conflicted’, ‘cli’, ‘dbplyr’, ‘dplyr’, ‘dtplyr’, ‘forcats’, ‘ggplot2’, ‘googledrive’, ‘googlesheets4’, ‘haven’, ‘hms’, ‘httr’, ‘jsonlite’, ‘lubridate’, ‘magrittr’, ‘modelr’, ‘pillar’, ‘purrr’, ‘ragg’, ‘readr’, ‘readxl’, ‘reprex’, ‘rlang’, ‘rst
# ...

# %%
# Install from CRAN
install.packages("vegan")
# Out:
# also installing the dependency ‘permute’
#
# Warning message in install.packages("vegan"):
# “installation of package ‘vegan’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
# Install from CRAN
install.packages("dplyr")
# Out:
# also installing the dependencies ‘fansi’, ‘utf8’, ‘cli’, ‘glue’, ‘lifecycle’, ‘magrittr’, ‘pillar’, ‘rlang’, ‘tibble’, ‘tidyselect’, ‘vctrs’
#
# Warning message in install.packages("dplyr"):
# “installation of package ‘fansi’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘utf8’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘cli’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘glue’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘magrittr’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘rlang’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘lifecycle’ had non-zero exit status”Warning message in install.packages("dplyr"):
# ...

# %%
# Install from CRAN
install.packages("ggplot2")
# Out:
# also installing the dependencies ‘colorspace’, ‘utf8’, ‘farver’, ‘munsell’, ‘fansi’, ‘magrittr’, ‘pillar’, ‘cli’, ‘glue’, ‘gtable’, ‘isoband’, ‘lifecycle’, ‘rlang’, ‘scales’, ‘tibble’, ‘vctrs’
#
# Warning message in install.packages("ggplot2"):
# “installation of package ‘colorspace’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘utf8’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘farver’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘fansi’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘magrittr’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘cli’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# ...

# %%
# Install from CRAN
install.packages("stringr")
# Out:
# also installing the dependencies ‘cli’, ‘glue’, ‘lifecycle’, ‘magrittr’, ‘rlang’, ‘stringi’, ‘vctrs’
#
# Warning message in install.packages("stringr"):
# “installation of package ‘cli’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘glue’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘magrittr’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘rlang’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘stringi’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘lifecycle’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘vctrs’ had non-zero exit status”Warning message in install.packages("stringr"):
# ...

# %%
library(tidyverse)
library(vegan)
library(dplyr)
library(ggplot2)
library(stringr)
# Out:
# Error in library(tidyverse): there is no package called ‘tidyverse’
# Traceback:
#
# 1. library(tidyverse)

# %%
installed.packages()["tidyverse", ]
# Out:
# Error in installed.packages()["tidyverse", ]: subscript out of bounds
# Traceback:

# %%
.libPaths()
# Out:
# [1] "/Users/carolinedesouza/anaconda3/envs/r-kernel/lib/R/library"

# %%
.libPaths(c(.libPaths(), "/path/to/tidyverse"))

# %%
install.packages("tidyverse", dependencies = TRUE)
# Out:
# also installing the dependencies ‘colorspace’, ‘sys’, ‘bit’, ‘cachem’, ‘farver’, ‘munsell’, ‘rappdirs’, ‘askpass’, ‘bit64’, ‘lazyeval’, ‘sass’, ‘fastmap’, ‘pkgbuild’, ‘rprojroot’, ‘diffobj’, ‘backports’, ‘ellipsis’, ‘lifecycle’, ‘memoise’, ‘blob’, ‘tidyselect’, ‘vctrs’, ‘data.table’, ‘gtable’, ‘isoband’, ‘scales’, ‘gargle’, ‘cellranger’, ‘curl’, ‘ids’, ‘rematch2’, ‘mime’, ‘openssl’, ‘timechange’, ‘fansi’, ‘utf8’, ‘systemfonts’, ‘textshaping’, ‘vroom’, ‘tzdb’, ‘progress’, ‘callr’, ‘fs’, ‘selectr’, ‘stringi’, ‘rex’, ‘yaml’, ‘highr’, ‘xfun’, ‘bslib’, ‘fontawesome’, ‘htmltools’, ‘jquerylib’, ‘tinytex’, ‘brio’, ‘desc’, ‘digest’, ‘pkgload’, ‘praise’, ‘processx’, ‘ps’, ‘waldo’, ‘broom’, ‘conflicted’, ‘cli’, ‘dbplyr’, ‘dplyr’, ‘dtplyr’, ‘forcats’, ‘ggplot2’, ‘googledrive’, ‘googlesheets4’, ‘haven’, ‘hms’, ‘httr’, ‘jsonlite’, ‘lubridate’, ‘magrittr’, ‘modelr’, ‘pillar’, ‘purrr’, ‘ragg’, ‘readr’, ‘readxl’, ‘reprex’, ‘rlang’, ‘rvest’, ‘stringr’, ‘tibble’, ‘tidyr’, ‘xml2’, ‘covr’, ‘feather’, ‘gl
# ...

# %%
installed_packages <- rownames(installed.packages())
"tidyverse" %in% installed_packages
# Out:
# [1] FALSE

# %%
install.packages("tidyverse")
# Out:
# also installing the dependencies ‘fastmap’, ‘colorspace’, ‘sys’, ‘bit’, ‘ps’, ‘sass’, ‘cachem’, ‘farver’, ‘munsell’, ‘rappdirs’, ‘askpass’, ‘bit64’, ‘processx’, ‘highr’, ‘xfun’, ‘yaml’, ‘bslib’, ‘fontawesome’, ‘htmltools’, ‘jquerylib’, ‘tinytex’, ‘backports’, ‘ellipsis’, ‘glue’, ‘lifecycle’, ‘memoise’, ‘blob’, ‘tidyselect’, ‘vctrs’, ‘data.table’, ‘gtable’, ‘isoband’, ‘scales’, ‘gargle’, ‘cellranger’, ‘curl’, ‘ids’, ‘rematch2’, ‘mime’, ‘openssl’, ‘timechange’, ‘fansi’, ‘utf8’, ‘systemfonts’, ‘textshaping’, ‘vroom’, ‘tzdb’, ‘progress’, ‘callr’, ‘fs’, ‘knitr’, ‘rmarkdown’, ‘selectr’, ‘stringi’, ‘broom’, ‘conflicted’, ‘cli’, ‘dbplyr’, ‘dplyr’, ‘dtplyr’, ‘forcats’, ‘ggplot2’, ‘googledrive’, ‘googlesheets4’, ‘haven’, ‘hms’, ‘httr’, ‘jsonlite’, ‘lubridate’, ‘magrittr’, ‘modelr’, ‘pillar’, ‘purrr’, ‘ragg’, ‘readr’, ‘readxl’, ‘reprex’, ‘rlang’, ‘rvest’, ‘stringr’, ‘tibble’, ‘tidyr’, ‘xml2’
#
# Warning message in install.packages("tidyverse"):
# ...

# %%
# Install from CRAN
install.packages("vegan")
# Out:
# Warning message in install.packages("vegan"):
# “installation of package ‘vegan’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
# Install from CRAN
install.packages("dplyr")
# Out:
# also installing the dependencies ‘fansi’, ‘utf8’, ‘cli’, ‘glue’, ‘lifecycle’, ‘magrittr’, ‘pillar’, ‘rlang’, ‘tibble’, ‘tidyselect’, ‘vctrs’
#
# Warning message in install.packages("dplyr"):
# “installation of package ‘fansi’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘utf8’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘cli’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘glue’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘magrittr’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘rlang’ had non-zero exit status”Warning message in install.packages("dplyr"):
# “installation of package ‘lifecycle’ had non-zero exit status”Warning message in install.packages("dplyr"):
# ...

# %%
# Install from CRAN
install.packages("ggplot2")
# Out:
# also installing the dependencies ‘colorspace’, ‘utf8’, ‘farver’, ‘munsell’, ‘fansi’, ‘magrittr’, ‘pillar’, ‘cli’, ‘glue’, ‘gtable’, ‘isoband’, ‘lifecycle’, ‘rlang’, ‘scales’, ‘tibble’, ‘vctrs’
#
# Warning message in install.packages("ggplot2"):
# “installation of package ‘colorspace’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘utf8’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘farver’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘fansi’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘magrittr’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# “installation of package ‘cli’ had non-zero exit status”Warning message in install.packages("ggplot2"):
# ...

# %%
# Install from CRAN
install.packages("stringr")
# Out:
# also installing the dependencies ‘cli’, ‘glue’, ‘lifecycle’, ‘magrittr’, ‘rlang’, ‘stringi’, ‘vctrs’
#
# Warning message in install.packages("stringr"):
# “installation of package ‘cli’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘glue’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘magrittr’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘rlang’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘stringi’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘lifecycle’ had non-zero exit status”Warning message in install.packages("stringr"):
# “installation of package ‘vctrs’ had non-zero exit status”Warning message in install.packages("stringr"):
# ...

# %%
library(tidyverse)
library(vegan)
library(dplyr)
library(ggplot2)
library(stringr)
# Out:
# Error in library(tidyverse): there is no package called ‘tidyverse’
# Traceback:
#
# 1. library(tidyverse)

# %%
installed.packages()["tidyverse", ]
# Out:
# Error in installed.packages()["tidyverse", ]: subscript out of bounds
# Traceback:

# %%
.libPaths()
# Out:
# [1] "/Users/carolinedesouza/anaconda3/envs/r-kernel/lib/R/library"

# %%
installed_packages <- rownames(installed.packages())
"tidyverse" %in% installed_packages
# Out:
# [1] FALSE

# %%
.libPaths(c(.libPaths(), "/path/to/tidyverse"))

# %%
install.packages("tidyverse", dependencies = TRUE)
# Out:
# also installing the dependencies ‘colorspace’, ‘sys’, ‘bit’, ‘cachem’, ‘farver’, ‘munsell’, ‘rappdirs’, ‘askpass’, ‘bit64’, ‘lazyeval’, ‘sass’, ‘fastmap’, ‘pkgbuild’, ‘diffobj’, ‘backports’, ‘ellipsis’, ‘lifecycle’, ‘memoise’, ‘blob’, ‘tidyselect’, ‘vctrs’, ‘data.table’, ‘gtable’, ‘isoband’, ‘scales’, ‘gargle’, ‘cellranger’, ‘curl’, ‘ids’, ‘rematch2’, ‘mime’, ‘openssl’, ‘timechange’, ‘fansi’, ‘utf8’, ‘systemfonts’, ‘textshaping’, ‘vroom’, ‘tzdb’, ‘progress’, ‘callr’, ‘fs’, ‘selectr’, ‘stringi’, ‘rex’, ‘yaml’, ‘highr’, ‘xfun’, ‘bslib’, ‘fontawesome’, ‘htmltools’, ‘jquerylib’, ‘tinytex’, ‘brio’, ‘desc’, ‘digest’, ‘pkgload’, ‘processx’, ‘ps’, ‘waldo’, ‘broom’, ‘conflicted’, ‘cli’, ‘dbplyr’, ‘dplyr’, ‘dtplyr’, ‘forcats’, ‘ggplot2’, ‘googledrive’, ‘googlesheets4’, ‘haven’, ‘hms’, ‘httr’, ‘jsonlite’, ‘lubridate’, ‘magrittr’, ‘modelr’, ‘pillar’, ‘purrr’, ‘ragg’, ‘readr’, ‘readxl’, ‘reprex’, ‘rlang’, ‘rvest’, ‘stringr’, ‘tibble’, ‘tidyr’, ‘xml2’, ‘covr’, ‘feather’, ‘glue’, ‘mockr’, ‘knitr’, 
# ...

# %%
library(tidyverse)
# Out:
# Error in library(tidyverse): there is no package called ‘tidyverse’
# Traceback:
#
# 1. library(tidyverse)

# %%
install.packages("tidyverse")
